# %% [markdown]
# # Sales Forecasting — Facebook Prophet
#
# **Model:** Prophet with multiplicative seasonality
# **Training data:** 2023 daily sales (all products combined)
# **Forecast horizon:** 30 days beyond 2024-12-31

# %%
import sys
from pathlib import Path

# Make src/ importable from the notebooks/ directory
sys.path.insert(0, str(Path("../src").resolve()))

# %% [markdown]
# ## Run the full forecasting pipeline

# %%
from forecast import run

pred, fig = run(show=False)  # show=False: we display inline below
# Out:
# 10:49:21 - cmdstanpy - INFO - Chain [1] start processing
# 10:49:21 - cmdstanpy - INFO - Chain [1] done processing
# Forecast saved to C:\Users\Sami\Documents\GitHub\saas-food-forecast\data\forecast.csv  (761 rows)
#         ds       yhat  yhat_lower  yhat_upper
# 2025-01-21 111.349726   57.950837  167.735508
# 2025-01-22 112.181874   62.438002  167.943554
# 2025-01-23 120.191474   66.239818  178.458200
# 2025-01-24 154.863282  100.333703  209.348343
# 2025-01-25 163.057169  107.741982  215.362063
# 2025-01-26 111.875771   57.058447  166.367915
# 2025-01-27 115.845245   63.854492  169.505205
# 2025-01-28 108.351052   53.232346  165.053956
# 2025-01-29 108.864008   57.875714  161.579289
# 2025-01-30 116.667591   63.180106  167.649300

# %% [markdown]
# ## Forecast chart

# %%
fig.show()

# %% [markdown]
# ## Forecast results — last 10 predicted days

# %%
import pandas as pd

forecast_df = pd.read_csv("../data/forecast.csv", parse_dates=["ds"])

print(f"Total forecast rows : {len(forecast_df)}")
print(f"Forecast period     : {forecast_df['ds'].min().date()} to {forecast_df['ds'].max().date()}")
print()

# Show only the 30 future days
future_only = forecast_df[forecast_df["ds"] > pd.Timestamp("2024-12-31")].copy()
future_only[["ds", "yhat", "yhat_lower", "yhat_upper"]] = future_only[
    ["ds", "yhat", "yhat_lower", "yhat_upper"]
].round(1)
display(future_only.reset_index(drop=True))
# Out:
# Total forecast rows : 761
# Forecast period     : 2023-01-01 to 2025-01-30
# C:\Users\Sami\AppData\Local\Temp\ipykernel_18104\362671161.py:13: UserWarning: obj.round has no effect with datetime, timedelta, or period dtypes. Use obj.dt.round(...) instead.
#   ].round(1)
#            ds   yhat  yhat_lower  yhat_upper
# 0  2025-01-01   96.2        42.0       146.8
# 1  2025-01-02  105.6        52.9       165.2
# 2  2025-01-03  141.7        93.3       195.8
# 3  2025-01-04  151.6       100.3       204.9
# 4  2025-01-05  102.6        48.3       158.5
# 5  2025-01-06  108.4        52.7       162.0
# 6  2025-01-07  102.8        48.8       156.0
# 7  2025-01-08  105.1        47.7       155.8
# 8  2025-01-09  114.6        57.1       169.0
# 9  2025-01-10  150.6        98.6       200.9
# 10 2025-01-11  160.2       103.5       214.9
# 11 2025-01-12  110.7        55.6       166.7
# 12 2025-01-13  116.0        61.9       166.6
# 13 2025-01-14  109.8        55.0       163.8
# ...
